# %% [markdown]
# ## Setup

# %%
home <- "/home/workspace/"
path <- "pbmc_flow/data/NDMM PB1 data - Statistics (2).csv"
util <- "pbmc_flow/utils.R"
cross_sectional_util <- "pbmc_flow/notebooks/flu_responder_cross_sectional/cross_sectional_utils.R"

source(file.path(home, util))
source(file.path(home, cross_sectional_util))

plot_path <- file.path(home, "pbmc_flow/plots/flu_response_cross_sectional_composition/bcells")
dir.create(plot_path, recursive = TRUE, showWarnings = FALSE)

celltypes <- c(
    "Plasmablasts",
    "Effector B cells",
    "IgM- Naive",
    "IgM+ Naive",
    "DN B cells",
    "Non switched effector",
    "IgA+ Memory",
    "Ig- memory",
    "IgG+ Memory",
    "Transitional B cells"
)

df <- read.csv(file.path(home, path))

df <- process_data(
    df,
    subject_col = "Subject",
    visit_col = "Flu.Visit",
    population_col = "population",
    percent_of_col = "percentOf",
    percent_col = "percent",
    plate_col = "plate",
    celltypes = celltypes,
    viable_filter = "Viable cells"
)

result <- freq_clr(
    freq_table = df,
    sample_col = "Sample_ID",
    freq_col = "frequency", 
    celltype_col = "population"
)

result$population <- factor(result$population, levels = celltypes)

# write.csv(result, "/home/workspace/pbmc_flow/data/tcell_composition_clr_results.csv", row.names = FALSE)

# %%
plots <- create_celltype_plots(
    result,
    plot_path,
    plot_title_prefix = "B cell Responders Compositions",
    filename_prefix = "bcell_responder_composition",
    response_var = "Flu.Response"
)

print(plots)
# Out:
# $`Flu Year 1 Day 0`
#
# $`Flu Year 1 Day 7`
# plot without title
# $`Flu Year 1 Day 90`
# plot without title
# $`Flu Year 1 Stand-Alone`
# plot without title
# $`Flu Year 2 Day 0`
# plot without title
# $`Flu Year 2 Day 7`
# plot without title
# $`Flu Year 2 Day 90`
# plot without title
# $`Flu Year 2 Stand-Alone`
# plot without title
# plot without title
